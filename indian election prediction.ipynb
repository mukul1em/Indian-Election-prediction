# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

plt.style.use('ggplot')

# %%
data=pd.read_csv(r'F:\mukulml\KAGGLE\LS_2.0.csv')

# %%
data.head()
# Out:
#            STATE CONSTITUENCY                   NAME  WINNER PARTY SYMBOL  \
# 0      Telangana     ADILABAD         SOYAM BAPU RAO       1   BJP  Lotus
# 1      Telangana     ADILABAD           Godam Nagesh       0   TRS    Car
# 2      Telangana     ADILABAD          RATHOD RAMESH       0   INC   Hand
# 3      Telangana     ADILABAD                   NOTA       0  NOTA    NaN
# 4  Uttar Pradesh         AGRA  Satyapal Singh Baghel       1   BJP  Lotus
#
#   GENDER CRIMINAL\nCASES   AGE CATEGORY      EDUCATION  \
# 0   MALE              52  52.0       ST      12th Pass
# 1   MALE               0  54.0       ST  Post Graduate
# 2   MALE               3  52.0       ST      12th Pass
# 3    NaN             NaN   NaN      NaN            NaN
# 4   MALE               5  58.0       SC      Doctorate
#
#                         ASSETS                  LIABILITIES  GENERAL\nVOTES  \
# 0    Rs 30,99,414\n ~ 30 Lacs+      Rs 2,31,450\n ~ 2 Lacs+          376892
# ...

# %%
data['PARTY'].value_counts()
# Out:
# BJP     420
# INC     413
# NOTA    245
# IND     201
# BSP     163
#        ...
# ABGP      1
# BLSD      1
# ravp      1
# CPIM      1
# JAPL      1
# Name: PARTY, Length: 133, dtype: int64

# %%
data['PARTY'][:10].value_counts().plot.bar(figsize=(30,10))

# %%
data.columns
# Out:
# Index(['STATE', 'CONSTITUENCY', 'NAME', 'WINNER', 'PARTY', 'SYMBOL', 'GENDER',
#        'CRIMINAL\nCASES', 'AGE', 'CATEGORY', 'EDUCATION', 'ASSETS',
#        'LIABILITIES', 'GENERAL\nVOTES', 'POSTAL\nVOTES', 'TOTAL\nVOTES',
#        'OVER TOTAL ELECTORS \nIN CONSTITUENCY',
#        'OVER TOTAL VOTES POLLED \nIN CONSTITUENCY', 'TOTAL ELECTORS'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# STATE                                          0
# CONSTITUENCY                                   0
# NAME                                           0
# WINNER                                         0
# PARTY                                          0
# SYMBOL                                       245
# GENDER                                       245
# CRIMINAL\nCASES                              245
# AGE                                          245
# CATEGORY                                     245
# EDUCATION                                    245
# ASSETS                                       245
# LIABILITIES                                  245
# GENERAL\nVOTES                                 0
# POSTAL\nVOTES                                  0
# TOTAL\nVOTES                                   0
# OVER TOTAL ELECTORS \nIN CONSTITUENCY          0
# OVER TOTAL VOTES POLLED \nIN CONSTITUENCY      0
# TOTAL ELECTORS                                 0
# dtype: int64

# %%
data.shape
# Out:
# (2263, 19)

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (2018, 19)

# %%
data
# Out:
#               STATE     CONSTITUENCY                    NAME  WINNER  PARTY  \
# 0         Telangana         ADILABAD          SOYAM BAPU RAO       1    BJP
# 1         Telangana         ADILABAD            Godam Nagesh       0    TRS
# 2         Telangana         ADILABAD           RATHOD RAMESH       0    INC
# 4     Uttar Pradesh             AGRA   Satyapal Singh Baghel       1    BJP
# 5     Uttar Pradesh             AGRA        Manoj Kumar Soni       0    BSP
# ...             ...              ...                     ...     ...    ...
# 2257    Maharashtra  YAVATMAL-WASHIM  Vaishali Sudhakar Yede       0  PHJSP
# 2258    Maharashtra  YAVATMAL-WASHIM      Anil Jayram Rathod       0    IND
# 2259      Telangana        ZAHIRABAD               B.B.PATIL       1    TRS
# 2260      Telangana        ZAHIRABAD         MADAN MOHAN RAO       0    INC
# 2261      Telangana        ZAHIRABAD      BANALA LAXMA REDDY       0    BJP
#
# ...

# %%
data.isna().sum()
# Out:
# STATE                                        0
# CONSTITUENCY                                 0
# NAME                                         0
# WINNER                                       0
# PARTY                                        0
# SYMBOL                                       0
# GENDER                                       0
# CRIMINAL\nCASES                              0
# AGE                                          0
# CATEGORY                                     0
# EDUCATION                                    0
# ASSETS                                       0
# LIABILITIES                                  0
# GENERAL\nVOTES                               0
# POSTAL\nVOTES                                0
# TOTAL\nVOTES                                 0
# OVER TOTAL ELECTORS \nIN CONSTITUENCY        0
# OVER TOTAL VOTES POLLED \nIN CONSTITUENCY    0
# TOTAL ELECTORS                               0
# dtype: int64

# %%
data.dtypes
# Out:
# STATE                                         object
# CONSTITUENCY                                  object
# NAME                                          object
# WINNER                                         int64
# PARTY                                         object
# SYMBOL                                        object
# GENDER                                        object
# CRIMINAL\nCASES                               object
# AGE                                          float64
# CATEGORY                                      object
# EDUCATION                                     object
# ASSETS                                        object
# LIABILITIES                                   object
# GENERAL\nVOTES                                 int64
# POSTAL\nVOTES                                  int64
# TOTAL\nVOTES                                   int64
# OVER TOTAL ELECTORS \nIN CONSTITUENCY        float64
# OVER TOTAL VOTES POLLED \nIN CONSTITUENCY    float64
# ...

# %%
data['EDUCATION'].value_counts().plot.bar(figsize=(20,10
                                                   ))

# %%
data['GENDER'].value_counts().plot.bar()

# %%
test=data['ASSETS'][:1].values.tolist()
test
# Out:
# ['Rs 30,99,414\n ~ 30 Lacs+']

# %%
def change_asset(x):
    try:
        value=(x.split('Rs')[1].split('\n')[0].strip())
        final_value=value.replace(",","")
        return final_value
    except:
        value=0
        return value

# %%
data['ASSETS']=data['ASSETS'].apply(change_asset)

# %%
data['LIABILITIES']=data['LIABILITIES'].apply(change_asset)

# %%
data.head()
# Out:
#            STATE CONSTITUENCY                   NAME  WINNER PARTY    SYMBOL  \
# 0      Telangana     ADILABAD         SOYAM BAPU RAO       1   BJP     Lotus
# 1      Telangana     ADILABAD           Godam Nagesh       0   TRS       Car
# 2      Telangana     ADILABAD          RATHOD RAMESH       0   INC      Hand
# 4  Uttar Pradesh         AGRA  Satyapal Singh Baghel       1   BJP     Lotus
# 5  Uttar Pradesh         AGRA       Manoj Kumar Soni       0   BSP  Elephant
#
#   GENDER CRIMINAL\nCASES   AGE CATEGORY      EDUCATION     ASSETS LIABILITIES  \
# 0   MALE              52  52.0       ST      12th Pass    3099414      231450
# 1   MALE               0  54.0       ST  Post Graduate   18477888      847000
# 2   MALE               3  52.0       ST      12th Pass   36491000    15300000
# 4   MALE               5  58.0       SC      Doctorate   74274036     8606522
# 5   MALE               0  47.0       SC  Post Graduate  133784385    22251891
#
# ...

# %%
data.dtypes
# Out:
# STATE                                         object
# CONSTITUENCY                                  object
# NAME                                          object
# WINNER                                         int64
# PARTY                                         object
# SYMBOL                                        object
# GENDER                                        object
# CRIMINAL\nCASES                               object
# AGE                                          float64
# CATEGORY                                      object
# EDUCATION                                     object
# ASSETS                                        object
# LIABILITIES                                   object
# GENERAL\nVOTES                                 int64
# POSTAL\nVOTES                                  int64
# TOTAL\nVOTES                                   int64
# OVER TOTAL ELECTORS \nIN CONSTITUENCY        float64
# OVER TOTAL VOTES POLLED \nIN CONSTITUENCY    float64
# ...

# %%
sn.countplot(data['GENDER'])

# %%
data['ASSETS']=data['ASSETS'].astype('int64')

# %%
data['LIABILITIES']=data['LIABILITIES'].astype('int64')

# %%
pd.crosstab(data['SYMBOL'],data['WINNER'])
# Out:
# WINNER                                     0   1
# SYMBOL
# A lady farmer carrying paddy on her head   8   1
# Air Conditioner                           11   0
# Almirah                                    4   0
# Apple                                      5   0
# Arrow                                      2  16
# ...                                       ..  ..
# Tyres                                      1   1
# Umbrella                                   1   0
# Walking Stick                             14   0
# Water Melon                                1   0
# Whistle                                    9   0
#
# [126 rows x 2 columns]

# %%
pd.crosstab(data['SYMBOL'],data['WINNER']).plot(figsize=(10,10))

# %%
pd.crosstab(data['CRIMINAL\nCASES'],data['WINNER']).plot()

# %%
plt.figure(figsize=(15,7))
sn.countplot(data['CRIMINAL\nCASES'],hue=data['WINNER'])

# %%
plt.figure(figsize=(15,7))
sn.countplot(data['EDUCATION'],hue=data['WINNER'])

# %%
plt.figure(figsize=(15,7))
sn.countplot(data['CATEGORY'],hue=data['WINNER'])

# %%
data.tail()
# Out:
#             STATE     CONSTITUENCY                    NAME  WINNER  PARTY  \
# 2257  Maharashtra  YAVATMAL-WASHIM  Vaishali Sudhakar Yede       0  PHJSP
# 2258  Maharashtra  YAVATMAL-WASHIM      Anil Jayram Rathod       0    IND
# 2259    Telangana        ZAHIRABAD               B.B.PATIL       1    TRS
# 2260    Telangana        ZAHIRABAD         MADAN MOHAN RAO       0    INC
# 2261    Telangana        ZAHIRABAD      BANALA LAXMA REDDY       0    BJP
#
#        SYMBOL  GENDER CRIMINAL\nCASES   AGE CATEGORY      EDUCATION  \
# 2257  Whistle  FEMALE               0  28.0  GENERAL      10th Pass
# 2258     SHIP    MALE               0  43.0  GENERAL  Post Graduate
# 2259      Car    MALE              18  63.0  GENERAL       Graduate
# 2260     Hand    MALE               0  49.0  GENERAL  Post Graduate
# 2261    Lotus    MALE               3  47.0  GENERAL      12th Pass
#
#           ASSETS  LIABILITIES  GENERAL\nVOTES  POSTAL\nVOTES  TOTAL\nVOTES  \
# ...

# %%
data.loc[data['CRIMINAL\nCASES']=='Not Available'].index
# Out:
# Int64Index([ 468,  532,  612,  613,  654,  656,  688,  972, 1033, 1052, 1126,
#             1309, 1681, 1696, 1716, 1938, 1971, 1978, 2069, 2188, 2223, 2249],
#            dtype='int64')

# %%
data.index=[i for i in range(data.shape[0])]

# %%
data.drop(data.index[[ 415,  472,  544,  545,  580,  582,  610,  864,  918,  933, 1000,
            1162, 1495, 1509, 1526, 1724, 1756, 1763, 1845, 1951, 1983, 2005]],inplace=True)

# %%
data.select_dtypes(include='object')
# Out:
#               STATE     CONSTITUENCY                    NAME  PARTY    SYMBOL  \
# 0         Telangana         ADILABAD          SOYAM BAPU RAO    BJP     Lotus
# 1         Telangana         ADILABAD            Godam Nagesh    TRS       Car
# 2         Telangana         ADILABAD           RATHOD RAMESH    INC      Hand
# 3     Uttar Pradesh             AGRA   Satyapal Singh Baghel    BJP     Lotus
# 4     Uttar Pradesh             AGRA        Manoj Kumar Soni    BSP  Elephant
# ...             ...              ...                     ...    ...       ...
# 2013    Maharashtra  YAVATMAL-WASHIM  Vaishali Sudhakar Yede  PHJSP   Whistle
# 2014    Maharashtra  YAVATMAL-WASHIM      Anil Jayram Rathod    IND      SHIP
# 2015      Telangana        ZAHIRABAD               B.B.PATIL    TRS       Car
# 2016      Telangana        ZAHIRABAD         MADAN MOHAN RAO    INC      Hand
# 2017      Telangana        ZAHIRABAD      BANALA LAXMA REDDY    BJP     Lotus
#
# ...

# %%
data['CRIMINAL\nCASES']=data['CRIMINAL\nCASES'].astype('int64')

# %%
data_categorical=data.select_dtypes(include='object')

# %%
data_categorical.head()
# Out:
#            STATE CONSTITUENCY                   NAME PARTY    SYMBOL GENDER  \
# 0      Telangana     ADILABAD         SOYAM BAPU RAO   BJP     Lotus   MALE
# 1      Telangana     ADILABAD           Godam Nagesh   TRS       Car   MALE
# 2      Telangana     ADILABAD          RATHOD RAMESH   INC      Hand   MALE
# 3  Uttar Pradesh         AGRA  Satyapal Singh Baghel   BJP     Lotus   MALE
# 4  Uttar Pradesh         AGRA       Manoj Kumar Soni   BSP  Elephant   MALE
#
#   CATEGORY      EDUCATION
# 0       ST      12th Pass
# 1       ST  Post Graduate
# 2       ST      12th Pass
# 3       SC      Doctorate
# 4       SC  Post Graduate

# %%
data['EDUCATION'].value_counts()
# Out:
# Post Graduate            502
# Graduate                 441
# Graduate Professional    336
# 12th Pass                256
# 10th Pass                196
# 8th Pass                  78
# Doctorate                 73
# Others                    50
# Literate                  30
# 5th Pass                  28
# Illiterate                 5
# Post Graduate\n            1
# Name: EDUCATION, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
def label_encoder(x):
    x=le.fit_transform(x)
    return x

# %%
data.select_dtypes(include='object').columns
# Out:
# Index(['STATE', 'CONSTITUENCY', 'NAME', 'PARTY', 'SYMBOL', 'GENDER',
#        'CATEGORY', 'EDUCATION'],
#       dtype='object')

# %%
data[['STATE', 'CONSTITUENCY', 'NAME', 'PARTY', 'SYMBOL', 'GENDER',
       'CATEGORY', 'EDUCATION']]=data[['STATE', 'CONSTITUENCY', 'NAME', 'PARTY', 'SYMBOL', 'GENDER',
       'CATEGORY', 'EDUCATION']].apply(label_encoder)

# %%
data.head()
# Out:
#    STATE  CONSTITUENCY  NAME  WINNER  PARTY  SYMBOL  GENDER  CRIMINAL\nCASES  \
# 0     31             0  1696       1     26      80       1               52
# 1     31             0   695       0    119      32       1                0
# 2     31             0  1485       0     46      66       1                3
# 3     33             1  1772       1     26      80       1                5
# 4     33             1  1110       0     35      49       1                0
#
#     AGE  CATEGORY  EDUCATION     ASSETS  LIABILITIES  GENERAL\nVOTES  \
# 0  52.0         2          1    3099414       231450          376892
# 1  54.0         2         10   18477888       847000          318665
# 2  52.0         2          1   36491000     15300000          314057
# 3  58.0         1          4   74274036      8606522          644459
# 4  47.0         1         10  133784385     22251891          434199
#
#    POSTAL\nVOTES  TOTAL\nVOTES  OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x=data.drop('WINNER',axis=1)

# %%
y=data['WINNER']

# %%
x=sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
classifier=LogisticRegression(C=1
                             )

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
classifier.fit(xtrain,ytrain)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
ypred=classifier.predict(xtest)

# %%
accuracy_score(ytest,ypred)
# Out:
# 0.9415692821368948

# %%
classifier=SVC(kernel='linear',C=10)

# %%
classifier.fit(xtrain,ytrain)
# Out:
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
ypred=classifier.predict(xtest)

# %%
accuracy_score(ypred,ytest)
# Out:
# 0.9432387312186978

# %%
classifier=RandomForestClassifier(n_estimators=100)

# %%
classifier.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
ypred=classifier.predict(xtest)

# %%
accuracy_score(ytest,ypred)
# Out:
# 0.9382303839732888
